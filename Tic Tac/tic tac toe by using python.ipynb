# %%
[Tic Tac Toe using python technics and alghorithims]

# %% [markdown]
# #AI Adversarial search:
# Adversarial search is a game-playing technique where the agents are surrounded by a competitive environment. A conflicting goal is given to the agents (multiagent). These agents compete with one another and try to defeat one another in order to win the game

# %%
Technics
the static evaluation function estimates board quality in leading to a win for one player.as we say that we
will use Tic-Tac-Toe as an example, the evalution function will be :
-1 for player ('O')
+1 for bot ('X')
0 for Tie
# Out:
#   File "<ipython-input-8-c1c86a27a6ef>", line 2
#     the static evaluation function estimates board quality in leading to a win for one player.as we say that we
#         ^
# SyntaxError: invalid syntax

# %%
#code
board={1:'o ',2:' ',3:' ',
       4:' ',5:' ',6:' ',
       7:' ',8:' ',9:' '}
def printBoard(board):
    print(board[1]+'|'+board[2]+'|'+board[3])
    print('-----')
    print(board[4] + '|' + board[5] + '|' + board[6])
    print('-----')
    print(board[7] + '|' + board[8] + '|' + board[9])
    print('-----')
    print('\n')
    printBoard(board)

def spacIsFree(position):
    if board[position == ' ']:
        return True
    else:
        return False


def checkDraw():
    for key in board.keys():
        if board[key]==' ':
            return False
    return True

def checkForWin():
    if(board[1]==board[2] and board[1]==board[3] and board[1]!=' '):
        return True
    elif(board[4]==board[5] and board[4]==board[6] and board[4]!=' '):
        return True
    elif(board[7]==board[8] and board[7]==board[9] and board[7]!=' '):
        return True
    elif(board[1]==board[4] and board[1]==board[7] and board[1]!=' '):
        return True
    elif(board[2]==board[5] and board[2]==board[8] and board[2]!=' '):
        return True
    elif (board[3] == board[6] and board[3] == board[9] and board[3] != ' '):
        return True
    elif (board[1] == board[5] and board[1] == board[9] and board[1] != ' '):
        return True
    elif (board[7] == board[5] and board[7] == board[3] and board[7] != ' '):
        return True
    else:
        return False

def checkWhichMarkWin(mark):
    if(board[1]==board[2] and board[1]==board[3] and board[1]!=' '):
        return True
    elif(board[4]==board[5] and board[4]==board[6] and board[4]!=' '):
        return True
    elif(board[7]==board[8] and board[7]==board[9] and board[7]!=' '):
        return True
    elif(board[1]==board[4] and board[1]==board[7] and board[1]!=' '):
        return True
    elif(board[2]==board[5] and board[2]==board[8] and board[2]!=' '):
        return True
    elif (board[3] == board[6] and board[3] == board[9] and board[3] != ' '):
        return True
    elif (board[1] == board[5] and board[1] == board[9] and board[1] != ' '):
        return True
    elif (board[7] == board[5] and board[7] == board[3] and board[7] != ' '):
        return True
    else:
        return False
def insertT(letter,position):
    if spacIsFree(position):
        board[position]==letter
        printBoard(board)
    if (checkDraw()):
        print('NICE Draw!')
        exit()
    if checkForWin():
        if letter=='x':
            print('Bot wins!')
            exit()
        else:
            print('player wins!')
            exit()
        return
    else:
        print('cant insetr there!')
        position=int(input("Enter new position:"))
        insertT(letter,position)
        return
player='o'
bot='x'
def playerMove():
    position=int(input("Enter the position for 'o':"))
    insertT(player, position)
    return
def compMove():
    bestScore=-1000
    bestMove=0
    for key in board.keys():
        if(board[key]==' '):
            board[key]=bot
            score=minimax(board,0,False)
            board[key]=' '
            if(score>bestScore):
                bestScore=score
                bestMove=key
    insertT(bot,bestMove)
    return

def minimax(board,depth,isMaximizing):
    if checkWhichMarkWin(bot):
        return 1
    elif checkWhichMarkWin(player):
        return -1
    elif checkDraw():
        return 0
    if isMaximizing:
        bestScore = -1000
        for key in board.keys():
            if (board[key] == ' '):
                board[key] = bot
                score = minimax(board, 0, False)
                board[key] = ' '
                if (score > bestScore):
                    bestScore = score
        return bestScore
    else:
        bestScore = 800
        for key in board.keys():
            if (board[key] == ' '):
                board[key] = bot
                score = minimax(board, 0, True)
                board[key] = ' '
                if (score < bestScore):
                    bestScore = score
        return bestScore

while not checkForWin():
    compMove()
    playerMove()

# %%
Methods:
-printboard:method that print the board element
-spacIsFree:make sure that positions are empty
-checkDraw:
-checkForWin:method that check for win, there are 4 ways to win:

 1- horizantally (rows).

 2- vertically (columns).

 3- main diagonal.

 4- reverse diagonal.

 If there is a win , win value will change to true and whoWins variable store the winner, and return True.
-playerMove:method that take player move as input and place it in the board
-compMove:bestScore=-1000
          bestMove=0
we check if score > bestScore, we change the value of bestScore to the value of score .
-minimax: method that take 3 parameters : board , depth and isMaximizing,termeiate state is indicated by "checkWhichMarkWin" 
method, if 'X' wins, return +1 , if 'O'win, return -1 ,return 0 for "checkDraw" method. 
(check "isMaximizing" value if it is true, that means the turn is for 'x' which try to maximaize it's performance, 
we declare variable called "bestScore" (-1000),we will traverse the board 
and generate all possibile moves by recurion of "minimax" method)
(If "isMax" value is false, that means the turn is for 'o' which try to minimaize 
 it's performance, we declare variable called "bestScore" (800)
# Out:
#   File "<ipython-input-11-a4bb6a5b34ee>", line 1
#     Methods:
#             ^
# SyntaxError: invalid syntax
